# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhilkumar91/Python/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Operators – Complete Guide
#
# This notebook covers all Python operators with clear examples:
# - Arithmetic
# - Assignment
# - Comparison
# - Logical
# - Bitwise
# - Membership
# - Identity

# %% [markdown]
# ## 1. Arithmetic Operators
# Used for mathematical calculations.

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponentiation: 1000

# %% [markdown]
# ## 2. Assignment Operators
# Used to assign values to variables.

# %%
x = 10
print("x =", x)

x += 5
print("x += 5 ->", x)

x -= 3
print("x -= 3 ->", x)

x *= 2
print("x *= 2 ->", x)

x /= 4
print("x /= 4 ->", x)

x %= 3
print("x %= 3 ->", x)
# Out:
# x = 10
# x += 5 -> 15
# x -= 3 -> 12
# x *= 2 -> 24
# x /= 4 -> 6.0
# x %= 3 -> 0.0

# %% [markdown]
# ## 3. Comparison Operators
# Used to compare two values.

# %%
a = 5
b = 10

print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)
# Out:
# a == b: False
# a != b: True
# a > b: False
# a < b: True
# a >= b: False
# a <= b: True

# %% [markdown]
# ## 4. Logical Operators
# Used to combine conditional statements.

# %%
x = True
y = False

print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)
# Out:
# x and y: False
# x or y: True
# not x: False

# %% [markdown]
# ## 5. Bitwise Operators
# Operate on binary values.

# %%
a = 5   # 101
b = 3   # 011

print("Bitwise AND:", a & b)
print("Bitwise OR:", a | b)
print("Bitwise XOR:", a ^ b)
print("Bitwise NOT:", ~a)
print("Left Shift:", a << 1)
print("Right Shift:", a >> 1)
# Out:
# Bitwise AND: 1
# Bitwise OR: 7
# Bitwise XOR: 6
# Bitwise NOT: -6
# Left Shift: 10
# Right Shift: 2

# %% [markdown]
# ## 6. Membership Operators
# Used to check presence in sequences.

# %%
nums = [1, 2, 3, 4, 5]

print("3 in nums:", 3 in nums)
print("10 not in nums:", 10 not in nums)
# Out:
# 3 in nums: True
# 10 not in nums: True

# %% [markdown]
# ## 7. Identity Operators
# Used to compare memory locations.

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]

print("a is b:", a is b)
print("a is c:", a is c)
print("a is not c:", a is not c)
# Out:
# a is b: True
# a is c: False
# a is not c: True

# %%
import math  # opening math library

# %%
len(dir(math))
# Out:
# 66

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import scipy.stats

# %%
math.factorial(5)
# Out:
# 120

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
2 ** 5
# Out:
# 32

# %%
pow(2,5)
# Out:
# 32

# %%
pow(2,5,5)
# Out:
# 2

# %%
pow(5,6,7,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3457603121.py in <cell line: 0>()
# ----> 1 pow(5,6,7,9)
#
# TypeError: pow() takes at most 3 arguments (4 given)
