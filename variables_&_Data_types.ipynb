# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhilkumar91/Python/blob/main/variables_%26_Data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction

# %%
print('Nikhil')
# Out:
# Nikhil

# %%
print(1000)
# Out:
# 1000

# %%
print(102.5646)
# Out:
# 102.5646

# %%
print("Data Science")
# Out:
# Data Science

# %% [markdown]
#                                  **variables**

# %%
a=10
a
# Out:
# 10

# %%
b=12.456

# %%
c='Vihara Tech'
c
# Out:
# 'Vihara Tech'

# %% [markdown]
# **Rules for declaring a variable**
#
# 1.   Do not start with the Digits
# 2.   Do not give more than one word
# 3.   Do not use special characters
# 4.   Variables are case sensitive in python

# %%
1a=10
# Out:
#   File "/tmp/ipython-input-3782790406.py", line 1
#     1a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
one two='hi'

# %%
%=65

# %%
city='Hyd'
print(CITY)

# %%
_1a=10
_1a

# %%
name_age='Nikhil 23'

# %% [markdown]
# We can declare multiple variables by using this method

# %%
a,b,c=10,20,30
a,b,c

# %%
hi,hello,namasthe="nikhil",10,15.25
hi,hello,namasthe

# %% [markdown]
# Data types

# %%
a=10
a
type(a)

# %%
b=12.45678
a
type(b)

# %%
c='hi'
type(c)

# %% [markdown]
# Type conversions

# %% [markdown]
# 1.int to float

# %%
import pandas as pd
a=10
b=pd.to_str(a)
b

# %%
a=10
print('the given variable is',a)

# %%
print('my name iS nikhil')
print('hi,  hello')

# %%
a=10
b=12.30
c='machine laerning'
print("%d members")

# %%
a='nikhil'
a[3],a[5]
print(a[3],a[5])
print(a[3]+a[5])
a.capitalize()
a
a.upper()

# %%
b='heLLo'
b.title()
# Out:
# 'Hello'

# %%
a='Hello python'
a[::2]
a[::3]
# Out:
# 'Hlph'

# %%
a=10
b=20
a is b
a is not b
# Out:
# True

# %%
a=10
b=10
a is b
# Out:
# True

# %%
print((6 + 3) - (6 + 3))
((5*10/6+100-56.33))
# Out:
# 0
# 52.00333333333333

# %%
a=[10,20,30,40,50]
b=[30,40,50]
c=20
d=30,40
print(b in a)
print(c in a)
print(d in a)
# Out:
# False
# True
# False

# %%
title='data science'
months=6
class_=1.30
print('Iam learning '+title+'in vihara tech for '+str(months)+'of daily hours of'+' '+str(class_))
# Out:
# Iam learning data sciencein vihara tech for 6of daily hours of 1.3

# %%
title='data science'
months=6
class_=1.30
print('Iam learning %s in vihara tech for %d months of daily hours of %f'%(title,months,class_))
# Out:
# Iam learning data science in vihara tech for 6 months of daily hours of 1.300000

# %%
age=21
print('My name is Nikhil and my age is %d'%age)
# Out:
# My name is Nikhil and my age is 21

# %%
age=21
print(f'My name is Nikhil and my age is {age}')
# Out:
# My name is Nikhil and my age is 21

# %%
title='data science'
months=6
class_=1.30
print(f'Iam learning {title} in vihara tech for {months} months of daily hours of {class_}')
# Out:
# Iam learning data science in vihara tech for 6 months of daily hours of 1.3

# %% [markdown]
# **reverse of a number**

# %%
a=456
b=a%10
c=a//10
d=c%10
e=c//10
reverse=int(str(b)+str(d)+str(e))
print(f'Reverse of a number 456 is {reverse}')
# Out:
# Reverse of a number 456 is 654

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
len(dir(str))
# Out:
# 81

# %%
a='hi hello world '
a.title()
# Out:
# 'Hi Hello World '

# %%
name1=list("hello")
name1[0]=name1[1]=5
print(name1)
name1[0]
# Out:
# [5, 5, 'l', 'l', 'o']
# 5

# %%
a='i.love.programming.language'
b=a.split('.')
b
# Out:
# ['i', 'love', 'programming', 'language']

# %%
c=b[::-1]
c
# Out:
# ['language', 'programming', 'love', 'i']

# %%
d='.'.join(c)
d
# Out:
# 'language.programming.love.i'

# %%
a='100.110.65'
b=chr(100)
c=chr(110)
d=chr(65)

print(b+c+d)
# Out:
# dnA

# %%
a='hi Iam Nikhil and Iam currently learning data science'
b=a.split()
print(b)
print(len(b))
c=' '.join(b)
print(c)
# Out:
# ['hi', 'Iam', 'Nikhil', 'and', 'Iam', 'currently', 'learning', 'data', 'science']
# 9
# hi Iam Nikhil and Iam currently learning data science

# %%
s='Nikhil'
count=0
for i in range(6):
  #print(ord(s[i]))
  if(ord(s[i])%2==0):
    count=count+ord(s[i])

print(count)
# Out:
# 290

# %%
a='i.love.programming.language'
b=a.split('.')
b
c=b[::-1]
c
print('.'.join(c))
# Out:
# language.programming.love.i

# %%
z='vishnu'
y=z.replace('v','W')
y
# Out:
# 'Wishnu'

# %%
a='Nikhil Kumar'
count=0
for i in range(len(a)):

  if(ord(a[i])%2==0):
    count+=ord(a[i])

print(count)
# Out:
# 436

# %%
mystring = "Pythonprogram"
print(mystring[:-2])
print(mystring[-4:-2])
# Out:
# Pythonprogr
# gr
